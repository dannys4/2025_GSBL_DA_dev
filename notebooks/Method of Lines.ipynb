# %%
using Revise
using HierarchicalDA
using LinearAlgebra
using Statistics
using Distributions
# Out:
# Precompiling HierarchicalDA
#   ✓ XML2_jll
#   ✓ CPUSummary
#   ✓ LightXML
#   ✓ PolyesterWeave
#   ✓ InfiniteArrays
#   ✓ BlockArrays
#   ✓ StatsBase
#   ✓ WriteVTK
#   ✓ InfiniteArrays → InfiniteArraysStatisticsExt
#   ✓ ToeplitzMatrices → ToeplitzMatricesStatsBaseExt
#   ✓ InfiniteArrays → InfiniteArraysDSPExt
#   ✓ FastTransforms
#   ✓ Distributions
#   ✓ Distributions → DistributionsTestExt
#   ✓ BandedMatrices
#   ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   ✓ BlockBandedMatrices
#   ✓ BlockBandedMatrices → BlockBandedMatricesSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceBlockBandedMatricesExt
#   ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   ✓ PreallocationTools
#   ✓ FiniteDiff
#   ✓ Polyester
#   ✓ FastBroadcast
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   ✓ ApproxFunBase
#   ✓ FiniteDiff → FiniteDiffBlockBandedMatricesExt
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
# ...

# %%
using CairoMakie
using LaTeXStrings

# %%
# Proably great to start with inv

# %%
Nx = 120
# Out:
# 120
